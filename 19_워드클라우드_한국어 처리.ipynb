# %%
import konlpy.tag

# %%
text = '''
야
너네 자랑하고 싶은 거 있으면 얼마든지 해
난 괜찮어
왜냐면 나는 부럽지가 않어
한 개도 부럽지가 않어
어?
너네 자랑하고 싶은 거 있으면 얼마든지 해
난 괜찮어
왜냐면 나는 부럽지가 않어
전혀 부럽지가 않어
니가 가진 게 많겠니
내가 가진 게 많겠니
난 잘 모르겠지만
한번 우리가 이렇게 한번
머리를 맞대고 생각을 해보자고
너한테 십만원이 있고
나한테 백만원이 있어
그러면 상당히 너는 내가 부럽겠지
짜증나겠지
근데 입장을 한번 바꿔서
우리가 생각을 해보자고
나는 과연 니 덕분에 행복할까...
'''

# %%
text1 = text.replace('.', '').replace('...','').replace(',','').replace("'","").replace('·', ' ').replace('=','').replace('\n','')

# %%
Okt = konlpy.tag.Okt()
Okt_morphs = Okt.pos(text1)  
print(Okt_morphs)
# Out:
# [('야', 'Exclamation'), ('너', 'Noun'), ('네', 'Josa'), ('자랑', 'Noun'), ('하고', 'Josa'), ('싶은', 'Verb'), ('거', 'Noun'), ('있으면', 'Adjective'), ('얼마', 'Noun'), ('든지', 'Josa'), ('해난', 'Noun'), ('괜찮어', 'Adjective'), ('왜냐면', 'Noun'), ('나', 'Noun'), ('는', 'Josa'), ('부럽지가', 'Adjective'), ('않어한', 'Verb'), ('개도', 'Noun'), ('부럽지가', 'Adjective'), ('않어어', 'Verb'), ('?', 'Punctuation'), ('너', 'Noun'), ('네', 'Josa'), ('자랑', 'Noun'), ('하고', 'Josa'), ('싶은', 'Verb'), ('거', 'Noun'), ('있으면', 'Adjective'), ('얼마', 'Noun'), ('든지', 'Josa'), ('해난', 'Noun'), ('괜찮어', 'Adjective'), ('왜냐면', 'Noun'), ('나', 'Noun'), ('는', 'Josa'), ('부럽지가', 'Adjective'), ('않어전혀', 'Verb'), ('부럽지가', 'Adjective'), ('않어니가', 'Verb'), ('가진', 'Verb'), ('게', 'Noun'), ('많겠니내가', 'Adjective'), ('가진', 'Verb'), ('게', 'Noun'), ('많겠니난', 'Adjective'), ('잘', 'Verb'), ('모르겠지만', 'Verb'), ('한번', 'Noun'), ('우리', 'Noun'), ('가', 'Josa'), ('이렇게', 'Adverb'), ('한번', 'Noun'), ('머리', 'Noun'), ('를', 'Josa'), ('맞대고', 'Verb'), ('생각', 'Noun'), ('을', 'Josa'), ('해보자고', 'Verb'), ('너', 'Noun'), ('한테', 'Josa'), ('십만원', 'Noun'), ('이', 'Josa'), ('있고', 'Adjective'), ('나', 'Noun'), ('한테', 'Josa'), ('백만원', 'Noun'), ('이', 'Josa'), ('있어', 'Adjective'), ('그러면', 'Adverb'), ('상당히', 'Adjective'), ('너', 'Noun'), ('는', 'Josa'), ('내', 'Noun'), ('가', 'Josa'), ('부럽겠지', 'Adjective'), ('짜증나겠지', 'Adjective'), ('근데', 'Adverb'), ('입장', 'Noun'), ('을', 'Josa'), ('한번', 'Noun'), ('바꿔서', 'Verb'), ('우리', 'Noun'), ('가', 'Josa'), ('생각', 'Noun'), ('을', 'Josa'), ('해보자고나는', 'Verb'), ('과연', 'Noun'), ('니', 'Noun'), ('덕분', 'Noun'), ('에', 'Josa'), ('행복할까', 'Adjective')]

# %%
Noun_words = []
for word, pos in Okt_morphs:
    if pos == 'Noun':
        Noun_words.append(word)
print(Noun_words)
# Out:
# ['너', '자랑', '거', '얼마', '해난', '왜냐면', '나', '개도', '너', '자랑', '거', '얼마', '해난', '왜냐면', '나', '게', '게', '한번', '우리', '한번', '머리', '생각', '너', '십만원', '나', '백만원', '너', '내', '입장', '한번', '우리', '생각', '과연', '니', '덕분']

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

wordcloud = WordCloud(font_path='malgun').generate(text)

# %%
plt.figure(figsize=(10,10))

plt.imshow(wordcloud)

plt.axis('off')
plt.show()

# %%
stopwords = ['내','너','니','나']
unique_Noun_words = set(Noun_words)
for word in unique_Noun_words:
    if word in stopwords:
        while word in Noun_words: Noun_words.remove(word)

# %%
from collections import Counter
c = Counter(Noun_words)
print(c.most_common(10))
# Out:
# [('한번', 3), ('자랑', 2), ('거', 2), ('얼마', 2), ('해난', 2), ('왜냐면', 2), ('게', 2), ('우리', 2), ('생각', 2), ('개도', 1)]

# %%
import wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from os import path

FONT_PATH = 'malgun' 
noun_text = ''
for word in Noun_words:
    noun_text = noun_text +' '+word

wordcloud = WordCloud(max_font_size=60, relative_scaling=.5, font_path=FONT_PATH).generate(noun_text) # generate() 는 하나의 string value를 입력 받음
plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
